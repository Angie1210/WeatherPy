# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# puerto ayora ec
# vardo no
# busselton au
# thompson ca
# tasiilaq gl
# connersville us
# chokurdakh ru
# upernavik gl
# barrow us
# east london za
# ushuaia ar
# richards bay za
# ushuaia ar
# barrow us
# kapaa us
# barrow us
# castro cl
# rikitea pf
# alice springs au
# arraial do cabo br
# ushuaia ar
# mataura pf
# cape town za
# bluff nz
# nohar in
# cordoba ar
# ilulissat gl
# nizhneyansk ru
# khatanga ru
# castro cl
# chokurdakh ru
# atuona pf
# pandan ph
# havoysund no
# ulladulla au
# salalah om
# barentsburg sj
# zaysan kz
# codrington ag
# barentsburg sj
# punta arenas cl
# severo-kurilsk ru
# dikson ru
# verkhnevilyuysk ru
# new norfolk au
# dikson ru
# ahipara nz
# kieta pg
# dikson ru
# guerrero negro mx
# saleaula ws
# albany au
# atuona pf
# newport us
# yellowknife ca
# hilo us
# ilulissat gl
# punta arenas cl
# anloga gh
# carnarvon au
# vestmannaeyjar is
# mataura pf
# khatanga ru
# bluff nz
# shimoda jp
# port alfred za
# batagay-alyta ru
# bredasdorp za
# ilulissat gl
# lokosovo ru
# vaini to
# aklavik ca
# russkaya polyana ru
# riyadh sa
# bluff nz
# bathsheba bb
# vila velha br
# castro cl
# souillac mu
# mataura pf
# saint george bm
# byron bay au
# sorland no
# cape town za
# castro cl
# atuona pf
# amapa br
# half moon bay us
# busselton au
# yellowknife ca
# belushya guba ru
# andenes no
# busselton au
# elk city us
# airai pw
# taolanaro mg
# hami cn
# atuona pf
# zhigansk ru
# markova ru
# sentyabrskiy ru
# leningradskiy ru
# albany au
# fengcheng cn
# fortuna us
# xiuyan cn
# rio grande br
# saskylakh ru
# lompoc us
# kapaa us
# ossora ru
# busselton au
# nemuro jp
# farafangana mg
# aklavik ca
# halalo wf
# hobyo so
# cabedelo br
# sentyabrskiy ru
# ribeira grande pt
# hermanus za
# ushuaia ar
# bredasdorp za
# taolanaro mg
# east london za
# plettenberg bay za
# obidos br
# jamestown sh
# bilibino ru
# barrow us
# busselton au
# thompson ca
# warqla dz
# bambous virieux mu
# cabo san lucas mx
# port elizabeth za
# olafsvik is
# alofi nu
# osinovo ru
# rikitea pf
# belushya guba ru
# castro cl
# kjollefjord no
# taolanaro mg
# cape town za
# belushya guba ru
# havelock us
# kavieng pg
# hilo us
# katsuura jp
# ponta do sol pt
# trairi br
# castro cl
# comodoro rivadavia ar
# kayerkan ru
# rikitea pf
# leningradskiy ru
# ushuaia ar
# ushuaia ar
# nikolskoye ru
# chokurdakh ru
# la ronge ca
# kota kinabalu my
# rikitea pf
# avarua ck
# atuona pf
# busselton au
# necochea ar
# lebu cl
# mount isa au
# sabla bg
# warqla dz
# lebu cl
# victoria sc
# hilo us
# albany au
# te anau nz
# hamilton us
# thompson ca
# kununurra au
# brun am
# rikitea pf
# inta ru
# ushuaia ar
# tiksi ru
# jega ng
# mataura pf
# codrington ag
# bartica gy
# jalu ly
# mataura pf
# constitucion mx
# rungata ki
# hobart au
# cherskiy ru
# qaanaaq gl
# mataura pf
# eldikan ru
# carnarvon au
# ushuaia ar
# lebu cl
# atuona pf
# east london za
# barbar sd
# kapaa us
# saint-philippe re
# busselton au
# tiksi ru
# illoqqortoormiut gl
# keti bandar pk
# pisco pe
# yar-sale ru
# ushuaia ar
# mataura pf
# ushuaia ar
# crotone it
# khatanga ru
# longyearbyen sj
# launceston au
# yar-sale ru
# sabzevar ir
# nanchang cn
# mataura pf
# nyuksenitsa ru
# ancud cl
# puerto ayora ec
# attawapiskat ca
# la ronge ca
# ancud cl
# hermanus za
# barentsburg sj
# luchegorsk ru
# rikitea pf
# rikitea pf
# opuwo na
# carutapera br
# estacion coahuila mx
# seoul kr
# ushuaia ar
# atuona pf
# karaul ru
# lebu cl
# jinchang cn
# rikitea pf
# busselton au
# pineville us
# albany au
# sioux lookout ca
# raudeberg no
# lixourion gr
# namibe ao
# iralaya hn
# barentsburg sj
# barentsburg sj
# toamasina mg
# mabaruma gy
# buala sb
# faya td
# rock hill us
# pemberton ca
# nhulunbuy au
# kahului us
# yellowknife ca
# la palma pa
# sentyabrskiy ru
# beisfjord no
# necochea ar
# ushuaia ar
# ushuaia ar
# barentsburg sj
# yinchuan cn
# independence us
# cherskiy ru
# mataura pf
# avarua ck
# klaksvik fo
# tromso no
# lompoc us
# sitka us
# vaini to
# kahului us
# faleapuna ws
# bambous virieux mu
# morant bay jm
# tete mz
# mataura pf
# sinnamary gf
# satitoa ws
# saint-francois gp
# bluff nz
# farap tm
# lixourion gr
# punta arenas cl
# gat ly
# nome us
# jabiru au
# new norfolk au
# fallon us
# isangel vu
# faanui pf
# hermanus za
# grande-riviere ca
# taolanaro mg
# konstantinovka ru
# hermanus za
# vaini to
# xichang cn
# rikitea pf
# san cristobal ec
# vanavara ru
# busselton au
# ancud cl
# hobart au
# dikson ru
# iqaluit ca
# saskylakh ru
# the valley ai
# sorland no
# new norfolk au
# taolanaro mg
# port alfred za
# georgetown sh
# yeppoon au
# ushuaia ar
# mafinga tz
# kapaa us
# amderma ru
# rocha uy
# makat kz
# nishihara jp
# chuy uy
# busselton au
# mataura pf
# vaini to
# nsanje mw
# codrington ag
# illoqqortoormiut gl
# floro no
# lolodorf cm
# nanortalik gl
# vaini to
# hermanus za
# ziro in
# rikitea pf
# hilo us
# mataura pf
# yellowknife ca
# busselton au
# khatanga ru
# kokuy ru
# thompson ca
# mount gambier au
# port elizabeth za
# aykhal ru
# namie jp
# sirsilla in
# san clemente cl
# ternate id
# bluff nz
# geraldton au
# ushuaia ar
# rikitea pf
# kapaa us
# atuona pf
# saskylakh ru
# bengkulu id
# salalah om
# marrakesh ma
# east london za
# iqaluit ca
# rikitea pf
# poum nc
# bundaberg au
# businga cd
# narsaq gl
# khorramshahr ir
# bredasdorp za
# ossora ru
# meulaboh id
# carnarvon au
# mahebourg mu
# pauini br
# brokopondo sr
# arraial do cabo br
# havelock us
# nikolskoye ru
# port macquarie au
# bambous virieux mu
# new norfolk au
# butaritari ki
# rikitea pf
# praia da vitoria pt
# newburgh gb
# barentsburg sj
# ancud cl
# sitka us
# busselton au
# almaznyy ru
# wilmington us
# namatanai pg
# northam au
# rikitea pf
# mataura pf
# namatanai pg
# kodiak us
# portland au
# salaspils lv
# kalmunai lk
# saint-francois gp
# mezen ru
# cherskiy ru
# veraval in
# hualmay pe
# rikitea pf
# san patricio mx
# bonavista ca
# okato nz
# albany au
# saskylakh ru
# saskylakh ru
# jamestown sh
# zhangjiakou cn
# ribeira grande pt
# maarianhamina fi
# busselton au
# carnarvon au
# mataura pf
# zverinogolovskoye ru
# nanortalik gl
# lebu cl
# bluff nz
# ploemeur fr
# qaanaaq gl
# sagua la grande cu
# nsanje mw
# lebu cl
# port hedland au
# nokaneng bw
# belushya guba ru
# wahran dz
# mount isa au
# cape town za
# palabuhanratu id
# palauig ph
# sheboygan us
# zhigansk ru
# margate za
# camacha pt
# barrow us
# jamestown sh
# tiksi ru
# laja cl
# leningradskiy ru
# alyangula au
# tilichiki ru
# lasa cn
# dikson ru
# kathu th
# illoqqortoormiut gl
# ostrovnoy ru
# albany au
# punta arenas cl
# satitoa ws
# iqaluit ca
# hilo us
# albany au
# jubb jannin lb
# tasiilaq gl
# saskylakh ru
# pisco pe
# chokurdakh ru
# sao joao da barra br
# tucuman ar
# ushuaia ar
# jamestown sh
# albany au
# shumerlya ru
# kendari id
# nizhneyansk ru
# kapaa us
# bredasdorp za
# jericho us
# ushuaia ar
# busselton au
# beringovskiy ru
# busselton au
# mitsamiouli km
# rikitea pf
# jurmala lv
# gorgan ir
# amberley nz
# ushuaia ar
# yamada jp
# turbat pk
# micomeseng gq
# mataura pf
# tuktoyaktuk ca
# albany au
# assela et
# hobart au
# ushuaia ar
# kelvington ca
# xichang cn
# nizhneyansk ru
# punta arenas cl
# barrow us
# souillac mu
# dikson ru
# rikitea pf
# arraial do cabo br
# samarai pg
# atar mr
# severo-kurilsk ru
# bredasdorp za
# barrow us
# kloulklubed pw
# murakami jp
# sarh td
# ende id
# albany au
# aasiaat gl
# key west us
# belushya guba ru
# arraial do cabo br
# plettenberg bay za
# tuatapere nz
# ushuaia ar
# ushuaia ar
# busselton au
# saint-philippe re
# klaksvik fo
# faanui pf
# mirabad af
# punta arenas cl
# mount isa au
# airai pw
# carnarvon au
# puerto ayora ec
# sentyabrskiy ru
# port lincoln au
# lompoc us
# ilulissat gl
# rikitea pf
# butaritari ki
# guerrero negro mx
# mahibadhoo mv
# carnarvon au
# mataura pf
# bluff nz
# nome us
# bose cn
# kavaratti in
# mogadishu so
# atuona pf
# ayame ci
# jamestown sh
# roma au
# tasiilaq gl
# bambous virieux mu
# avarua ck
# kodiak us
# namibe ao
# rikitea pf
# malakal sd
# bredasdorp za
# cabo san lucas mx
# payakumbuh id
# port lincoln au
# mataura pf
# mendahara id
# barrow us
# adana tr
# hermanus za
# ushuaia ar
# rikitea pf
# victoria sc
# hofn is
# cherskiy ru
# qaanaaq gl
# mpika zm
# ushuaia ar
# sasovo ru
# ushuaia ar
# severo-kurilsk ru
# rikitea pf
# castro cl
# hobart au
# port elizabeth za
# soissons fr
# avarua ck
# mount isa au
# brainerd us
# vaini to
# kodinsk ru
# leningradskiy ru
# cidreira br
# kariba zw
# avarua ck
# ushuaia ar
# punta arenas cl
# karaul ru
# tsihombe mg
# leningradskiy ru
# rikitea pf
# deputatskiy ru
# pulawy pl
# hermanus za
# ashta in
# the pas ca
# rikitea pf
# rikitea pf
# ushuaia ar
# amderma ru
# ancud cl
# arraial do cabo br
# illoqqortoormiut gl
# coihueco cl
# nizhneyansk ru
# atuona pf
# busselton au
# new norfolk au
# alihe cn
# port hardy ca
# cape town za
# vryburg za
# punta arenas cl
# cockburn town bs
# nizhneyansk ru
# ushuaia ar
# palabuhanratu id
# basoko cd
# port lincoln au
# vila velha br
# dujuma so
# busselton au
# rawah iq
# illoqqortoormiut gl
# inhambane mz
# umzimvubu za
# new norfolk au
# tilichiki ru
# puerto ayora ec
# novoilinsk ru
# barentsburg sj
# bluff nz
# illoqqortoormiut gl
# berezanka ua
# kruisfontein za
# ushuaia ar
# bluff nz
# rikitea pf
# saint george bm
# airai pw
# meyungs pw
# torbay ca
# albany au
# georgetown sh
# kapaa us
# itarema br
# san patricio mx
# fortuna us
# muroto jp
# utiroa ki
# mount pleasant us
# gari ru
# ormara pk
# saleaula ws
# mataura pf
# rikitea pf
# port hardy ca
# pemangkat id
# siguiri gn
# keti bandar pk
# illoqqortoormiut gl
# mandera ke
# ushuaia ar
# jamestown sh
# esperance au
# hermanus za
# nikolskoye ru
# taolanaro mg
# cascais pt
# hobart au
# hithadhoo mv
# hilo us
# mys shmidta ru
# ushuaia ar
# ayan ru
# salta ar
# hermanus za
# narsaq gl
# hermanus za
# dikson ru
# punta arenas cl
# tasiilaq gl
# rikitea pf
# puerto ayora ec
# tuktoyaktuk ca
# cape town za
# rikitea pf
# upernavik gl
# rindal no
# carutapera br
# palabuhanratu id
# tiksi ru
# hilo us
# henties bay na
# kapaa us
# seoul kr
# northam au
# benguela ao
# souillac mu
# vaini to
# esperance au
# sakakah sa
# avarua ck
# norman wells ca
# kragero no
# ushuaia ar
# ahipara nz
# paita pe
# albany au
# san jose cr
# port blair in
# necochea ar
# mahebourg mu
# rikitea pf
# narsaq gl
# port alfred za
# nanortalik gl
# lebu cl
# constitucion mx
# norman wells ca
# rikitea pf
# petropavlovsk-kamchatskiy ru
# pevek ru
# talnakh ru
# samusu ws
# burnie au
# araouane ml
# tiksi ru
# tessalit ml
# esil kz
# bluff nz
# marzuq ly
# punta arenas cl
# belushya guba ru
# severo-yeniseyskiy ru
# chokurdakh ru
# inhambane mz
# bluff nz
# pringsewu id
# aykhal ru
# sur om
# ribeira grande pt
# ushuaia ar
# hermanus za
# vaitupu wf
# santa cruz de la palma es
# yellowknife ca
# chuy uy
# tasiilaq gl
# sola vu
# tiksi ru
# punta arenas cl
# libenge cd
# butaritari ki
# ushuaia ar
# thompson ca
# butaritari ki
# amderma ru
# busselton au
# muros es
# lompoc us
# cherskiy ru
# kibala ao
# ca mau vn
# san pedro bo
# ushuaia ar
# sistranda no
# port hawkesbury ca
# huoqiu cn
# sao filipe cv
# faanui pf
# grand gaube mu
# babanusah sd
# lagoa pt
# taolanaro mg
# albany au
# punta arenas cl
# khatanga ru
# busselton au
# hami cn
# kapaa us
# rio gallegos ar
# barentsburg sj
# atuona pf
# avarua ck
# busselton au
# arraial do cabo br
# ushuaia ar
# albany au
# belaya gora ru
# evensk ru
# esperance au
# new norfolk au
# umea se
# inuvik ca
# punta arenas cl
# butaritari ki
# chandur in
# tiarei pf
# vaini to
# cherskiy ru
# wum cm
# namibe ao
# eureka us
# nizhneyansk ru
# avarua ck
# atuona pf
# marcona pe
# urdzhar kz
# mataura pf
# mantua cu
# tasiilaq gl
# tuatapere nz
# ribeira grande pt
# hermanus za
# busselton au
# shahpur in
# mujiayingzi cn
# albany au
# aklavik ca
# lavrentiya ru
# manokwari id
# lagoa pt
# vaini to
# bambous virieux mu
# busselton au
# grindavik is
# bakaly ru
# hermanus za
# rikitea pf
# tiksi ru
# salina us
# concarneau fr
# nikolskoye ru
# zhangye cn
# klaksvik fo
# barrow us
# gizo sb
# taolanaro mg
# barentsburg sj
# burnie au
# murgab tm
# port hedland au
# airai pw
# rikitea pf
# ino jp
# gao ml
# bushehr ir
# east london za
# warqla dz
# iqaluit ca
# bluff nz
# kavieng pg
# mar del plata ar
# punta arenas cl
# tasiilaq gl
# louisbourg ca
# hamilton bm
# ballina ie
# caxito ao
# meyungs pw
# rikitea pf
# hermanus za
# zabid ye
# khandyga ru
# hasaki jp
# shipitsyno ru
# hasaki jp
# taolanaro mg
# yanan cn
# hobart au
# praya id
# cidreira br
# port-gentil ga
# hobart au
# khatanga ru
# kodinsk ru
# torbay ca
# busselton au
# nanortalik gl
# albany au
# pevek ru
# anadyr ru
# wuwei cn
# ushuaia ar
# barrow us
# axim gh
# puerto ayora ec
# tasiilaq gl
# westport ie
# belushya guba ru
# epe ng
# amderma ru
# geraldton au
# saint george bm
# rudbar af
# tuktoyaktuk ca
# chuy uy
# te anau nz
# punta arenas cl
# opuwo na
# zhanatas kz
# santarem br
# taolanaro mg
# ushuaia ar
# mataura pf
# bredasdorp za
# gravelbourg ca
# grand gaube mu
# hilo us
# plouzane fr
# fare pf
# rikitea pf
# nosy varika mg
# tacoronte es
# ushuaia ar
# pyay mm
# tasiilaq gl
# pisco pe
# busselton au
# umzimvubu za
# avarua ck
# pangnirtung ca
# thinadhoo mv
# albany au
# taolanaro mg
# pacific grove us
# grenaa dk
# kapaa us
# nizhneyansk ru
# tuktoyaktuk ca
# dawson creek ca
# gravdal no
# kurilsk ru
# shakawe bw
# buin pg
# chapais ca
# mataura pf
# kjollefjord no
# mehamn no
# taolanaro mg
# kavieng pg
# yellowknife ca
# pangnirtung ca
# torbay ca
# honiara sb
# bowen au
# lebu cl
# ola ru
# yelniki ru
# mataura pf
# rikitea pf
# nizhneyansk ru
# the valley ai
# attawapiskat ca
# bykovo ru
# svetlogorsk ru
# coahuayana mx
# arraial do cabo br
# college us
# saint george bm
# nikolskoye ru
# kodiak us
# vaini to
# poya nc
# taolanaro mg
# faanui pf
# blagoyevo ru
# hermanus za
# ushuaia ar
# acapulco mx
# vaitupu wf
# bluff nz
# ushuaia ar
# tommot ru
# kysyl-syr ru
# inuvik ca
# qaanaaq gl
# vilhena br
# bargal so
# bud no
# naples us
# khani ru
# rikitea pf
# upernavik gl
# burgeo ca
# sakaiminato jp
# jiddah sa
# hilo us
# kapaa us
# butaritari ki
# port alfred za
# faanui pf
# sinnamary gf
# ugoofaaru mv
# belushya guba ru
# manggar id
# hobart au
# saint-pierre pm
# bambous virieux mu
# leningradskiy ru
# tsihombe mg
# cape town za
# rikitea pf
# golyshmanovo ru
# punta arenas cl
# tuatapere nz
# mataura pf
# mys shmidta ru
# miandrivazo mg
# arraial do cabo br
# victoria sc
# mahebourg mu
# calamar co
# narsaq gl
# cape town za
# bay roberts ca
# ixtapa mx
# barsi in
# tiksi ru
# phonhong la
# norman wells ca
# vaitupu wf
# kruisfontein za
# nikolskoye ru
# rikitea pf
# hermanus za
# busselton au
# mataura pf
# albany au
# northam au
# stornoway gb
# mango tg
# saint george bm
# new norfolk au
# kavieng pg
# qaanaaq gl
# talnakh ru
# portland au
# yeletskiy ru
# ushuaia ar
# qaanaaq gl
# tasiilaq gl
# lazaro cardenas mx
# atuona pf
# innisfail au
# cap malheureux mu
# saint-philippe re
# mar del plata ar
# avarua ck
# busselton au
# altos br
# rikitea pf
# ahipara nz
# huntington us
# atlantic city us
# thompson ca
# tazovskiy ru
# nikolskoye ru
# saint anthony ca
# vestmannaeyjar is
# rikitea pf
# chuy uy
# saleaula ws
# alghero it
# rikitea pf
# kangaatsiaq gl
# taolanaro mg
# rodrigues alves br
# ribeira grande pt
# attawapiskat ca
# mataura pf
# tasiilaq gl
# illoqqortoormiut gl
# kibala ao
# jamestown sh
# nenjiang cn
# atyrau kz
# vostok ru
# harper lr
# hermanus za
# punta arenas cl
# upernavik gl
# jamestown sh
# katsuura jp
# bluff nz
# punta arenas cl
# cape town za
# vytegra ru
# nizhneyansk ru
# constantine dz
# punta arenas cl
# izumo jp
# inirida co
# bubaque gw
# ushuaia ar
# maymyo mm
# new norfolk au
# albany au
# bubaque gw
# nurmijarvi fi
# hobart au
# nizhneyansk ru
# punta arenas cl
# garhshankar in
# hobart au
# punta arenas cl
# port hedland au
# takoradi gh
# opuwo na
# scarborough gb
# bluff nz
# marsabit ke
# barrow us
# fort wellington gy
# paveh ir
# busselton au
# neiafu to
# kashan ir
# kaka tm
# narsaq gl
# kahului us
# kavieng pg
# kapaa us
# nikolskoye ru
# isangel vu
# eganville ca
# matagami ca
# busselton au
# chuy uy
# qinzhou cn
# keetmanshoop na
# khatanga ru
# ushuaia ar
# hobart au
# guadalajara es
# morondava mg
# provideniya ru
# the valley ai
# woodward us
# tiksi ru
# vaini to
# bambous virieux mu
# kapaa us
# rikitea pf
# tuatapere nz
# high level ca
# bathurst ca
# kununurra au
# touros br
# saint george bm
# katherine au
# new norfolk au
# mount gambier au
# chokurdakh ru
# albany au
# pangkalanbuun id
# clyde river ca
# khatanga ru
# mataura pf
# vaini to
# hermanus za
# altay cn
# caxito ao
# albany au
# koutsouras gr
# kindia gn
# maloy no
# albany au
# yelabuga ru
# cabo san lucas mx
# jamestown sh
# hilo us
# burica pa
# nioki cd
# wattegama lk
# xiongzhou cn
# kapaa us
# punta arenas cl
# ushuaia ar
# morgan city us
# lagoa pt
# east london za
# khatanga ru
# rikitea pf
# punta arenas cl
# hobart au
# faanui pf
# bambous virieux mu
# kodiak us
# ancud cl
# pisco pe
# menongue ao
# port shepstone za
# teknaf bd
# klaksvik fo
# jamestown sh
# posse br
# vaini to
# tumannyy ru
# atuona pf
# busselton au
# khatanga ru
# talnakh ru
# novikovo ru
# clyde river ca
# itoman jp
# salalah om
# deputatskiy ru
# vila velha br
# prince albert ca
# nizhneyansk ru
# rikitea pf
# hermanus za
# nikel ru
# albany au
# taolanaro mg
# naze jp
# ushuaia ar
# butaritari ki
# khatanga ru
# pitmoaga bf
# ribeira grande pt
# vavozh ru
# kayerkan ru
# sao filipe cv
# ishigaki jp
# punta arenas cl
# tigil ru
# punta arenas cl
# mahebourg mu
# victoria sc
# vaini to
# hilo us
# kamenka ru
# grindavik is
# lavrentiya ru
# yellowknife ca
# ushuaia ar
# qaanaaq gl
# sao miguel do araguaia br
# albanel ca
# torbay ca
# albanel ca
# busselton au
# ormara pk
# bluff nz
# taolanaro mg
# rikitea pf
# mataura pf
# venado tuerto ar
# kysyl-syr ru
# esperance au
# lata sb
# luderitz na
# bonthe sl
# homa bay ke
# dikson ru
# albany au
# rikitea pf
# luderitz na
# yellowknife ca
# vaini to
# karpogory ru
# katsuura jp
# cape town za
# torbay ca
# kavieng pg
# nhulunbuy au
# atuona pf
# bambous virieux mu
# cape town za
# hilo us
# hilo us
# kapaa us
# pietarsaari fi
# hobart au
# barrow us
# nikolskoye ru
# carnarvon au
# the valley ai
# kinablangan ph
# bethel us
# hasaki jp
# alofi nu
# portland au
# ushuaia ar
# saint-philippe re
# taolanaro mg
# hermanus za
# ilulissat gl
# castro cl
# puerto ayora ec
# padang id
# alexandria eg
# belushya guba ru
# leh in
# tiksi ru
# rikitea pf
# finschhafen pg
# mirnyy ru
# busselton au
# alice springs au
# arraial do cabo br
# mataura pf
# jatibonico cu
# hami cn
# port elizabeth za
# cape town za
# khatanga ru
# fougamou ga
# taolanaro mg
# tuktoyaktuk ca
# illoqqortoormiut gl
# vaini to
# hobart au
# hirara jp
# ushuaia ar
# ishigaki jp
# punta arenas cl
# hasaki jp
# mangan in
# kapaa us
# tuktoyaktuk ca
# hami cn
# nikolskoye ru
# kruisfontein za
# college us
# vagur fo
# rikitea pf
# port alfred za
# victoria sc
# saint-philippe re
# souillac mu
# broken hill au
# ushuaia ar
# punta arenas cl
# torbay ca
# kaitangata nz
# touros br
# bengkulu id
# mataura pf
# rikitea pf
# kargil in
# serchhip in
# atuona pf
# mantua cu
# hasaki jp
# saint anthony ca
# atuona pf
# amderma ru
# hobart au
# talaya ru
# sechura pe
# iqaluit ca
# rajgarh in
# bredasdorp za
# asosa et
# rikitea pf
# kegayli uz
# hobart au
# taolanaro mg
# port alfred za
# ushuaia ar
# ponta do sol cv
# tame co
# salalah om
# tuktoyaktuk ca
# vostok ru
# ushuaia ar
# camopi gf
# punta arenas cl
# ushuaia ar
# albany au
# hermanus za
# qaanaaq gl
# atuona pf
# lompoc us
# twentynine palms us
# aripuana br
# sarnia ca
# hermanus za
# vaini to
# suntar ru
# kommunisticheskiy ru
# caravelas br
# attawapiskat ca
# kodiak us
# upernavik gl
# hilo us
# tasiilaq gl
# nizhneyansk ru
# rikitea pf
# albany au
# zhanakorgan kz
# yar-sale ru
# atuona pf
# anan jp
# pevek ru
# chenghai cn
# san cristobal ec
# beyneu kz
# kirillov ru
# ballina au
# chuy uy
# port alfred za
# abha sa
# upernavik gl
# taolanaro mg
# barrow us
# hokitika nz
# luau ao
# avera pf
# thompson ca
# avarua ck
# samalaeulu ws
# east london za
# butaritari ki
# doctor pedro p. pena py
# batangafo cf
# norman wells ca
# albany au
# kaitangata nz
# taolanaro mg
# kapaa us
# saint george bm
# peleduy ru
# saldanha za
# nikolskoye ru
# mahebourg mu
# oussouye sn
# cape town za
# saint-georges gf
# el tigre ve
# busselton au
# cidreira br
# uroteppa tj
# svetlogorsk ru
# maniitsoq gl
# avarua ck
# butaritari ki
# dikson ru
# taolanaro mg
# mar del plata ar
# cuencame mx
# busselton au
# dolores ar
# ushuaia ar
# belushya guba ru
# labuhan id
# hamilton bm
# samarai pg
# outjo na
# kuche cn
# berlevag no
# acapulco mx
# albany au
# butaritari ki
# san quintin mx
# pilar ph
# busselton au
# sitka us
# liberec cz
# guarapari br
# sioux lookout ca
# bredasdorp za
# busselton au
# vaini to
# salalah om
# fonte boa br
# jerico co
# bilibino ru
# aswan eg
# mayo ca
# ushuaia ar
# rikitea pf
# ushuaia ar
# hithadhoo mv
# el ocotito mx
# mataura pf
# machaneng bw
# torbay ca
# illoqqortoormiut gl
# chicama pe
# ushuaia ar
# vaini to
# albany au

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 621

# %%
cities
# Out:
# ['puerto ayora',
#  'vardo',
#  'busselton',
#  'thompson',
#  'tasiilaq',
#  'connersville',
#  'chokurdakh',
#  'upernavik',
#  'barrow',
#  'east london',
#  'ushuaia',
#  'richards bay',
#  'kapaa',
#  'castro',
#  'rikitea',
#  'alice springs',
#  'arraial do cabo',
#  'mataura',
#  'cape town',
#  'bluff',
#  'nohar',
#  'cordoba',
#  'ilulissat',
#  'nizhneyansk',
#  'khatanga',
#  'atuona',
#  'pandan',
#  'havoysund',
#  'ulladulla',
#  'salalah',
#  'barentsburg',
#  'zaysan',
#  'codrington',
#  'punta arenas',
#  'severo-kurilsk',
#  'dikson',
#  'verkhnevilyuysk',
#  'new norfolk',
#  'ahipara',
#  'kieta',
#  'guerrero negro',
#  'saleaula',
#  'albany',
#  'newport',
#  'yellowknife',
#  'hilo',
#  'anloga',
#  'carnarvon',
#  'vestmannaeyjar',
#  'shimoda',
#  'port alfred',
#  'batagay-alyta',
#  'bredasdorp',
#  'lokosovo',
#  'vaini',
#  'aklavik',
#  'russkaya polyana',
#  'riyadh',
#  'bathsheba',
#  'vila velha',
#  'souillac',
#  'saint george',
#  'byron bay',
#  'sorland',
#  'amapa',
#  'half moon bay',
#  'belushya guba',
#  'andenes',
#  'elk city',
#  'airai',
#  'taolanaro',
#  'hami',
#  'zhigansk',
#  'markova',
#  'sentyabrskiy',
#  'leningradskiy',
#  'fengcheng',
#  'fortuna',
#  'xiuyan',
#  'rio grande',
#  'saskylakh',
#  'lompoc',
#  'ossora',
#  'nemuro',
#  'farafangana',
#  'halalo',
#  'hobyo',
#  'cabedelo',
#  'ribeira grande',
#  'hermanus',
#  'plettenberg bay',
#  'obidos',
#  'jamestown',
#  'bilibino',
#  'warqla',
#  'bambous virieux',
#  'cabo san lucas',
#  'port elizabeth',
#  'olafsvik',
#  'alofi',
#  'osinovo',
#  'kjollefjord',
#  'havelock',
#  'kavieng',
#  'katsuura',
#  'ponta do sol',
#  'trairi',
#  'comodoro rivadavia',
#  'kayerkan',
#  'nikolskoye',
#  'la ronge',
#  'kota kinabalu',
#  'avarua',
#  'necochea',
#  'lebu',
#  'mount isa',
#  'sabla',
#  'victoria',
#  'te anau',
#  'hamilton',
#  'kununurra',
#  'brun',
#  'inta',
#  'tiksi',
#  'jega',
#  'bartica',
#  'jalu',
#  'constitucion',
#  'rungata',
#  'hobart',
#  'cherskiy',
#  'qaanaaq',
#  'eldikan',
#  'barbar',
#  'saint-philippe',
#  'illoqqortoormiut',
#  'keti bandar',
#  'pisco',
#  'yar-sale',
#  'crotone',
#  'longyearbyen',
#  'launceston',
#  'sabzevar',
#  'nanchang',
#  'nyuksenitsa',
#  'ancud',
#  'attawapiskat',
#  'luchegorsk',
#  'opuwo',
#  'carutapera',
#  'estacion coahuila',
#  'seoul',
#  'karaul',
#  'jinchang',
#  'pineville',
#  'sioux lookout',
#  'raudeberg',
#  'lixourion',
#  'namibe',
#  'iralaya',
#  'toamasina',
#  'mabaruma',
#  'buala',
#  'faya',
#  'rock hill',
#  'pemberton',
#  'nhulunbuy',
#  'kahului',
#  'la palma',
#  'beisfjord',
#  'yinchuan',
#  'independence',
#  'klaksvik',
#  'tromso',
#  'sitka',
#  'faleapuna',
#  'morant bay',
#  'tete',
#  'sinnamary',
#  'satitoa',
#  'saint-francois',
#  'farap',
#  'gat',
#  'nome',
#  'jabiru',
#  'fallon',
#  'isangel',
#  'faanui',
#  'grande-riviere',
#  'konstantinovka',
#  'xichang',
#  'san cristobal',
#  'vanavara',
#  'iqaluit',
#  'the valley',
#  'georgetown',
#  'yeppoon',
#  'mafinga',
#  'amderma',
#  'rocha',
#  'makat',
#  'nishihara',
#  'chuy',
#  'nsanje',
#  'floro',
#  'lolodorf',
#  'nanortalik',
#  'ziro',
#  'kokuy',
#  'mount gambier',
#  'aykhal',
#  'namie',
#  'sirsilla',
#  'san clemente',
#  'ternate',
#  'geraldton',
#  'bengkulu',
#  'marrakesh',
#  'poum',
#  'bundaberg',
#  'businga',
#  'narsaq',
#  'khorramshahr',
#  'meulaboh',
#  'mahebourg',
#  'pauini',
#  'brokopondo',
#  'port macquarie',
#  'butaritari',
#  'praia da vitoria',
#  'newburgh',
#  'almaznyy',
#  'wilmington',
#  'namatanai',
#  'northam',
#  'kodiak',
#  'portland',
#  'salaspils',
#  'kalmunai',
#  'mezen',
#  'veraval',
#  'hualmay',
#  'san patricio',
#  'bonavista',
#  'okato',
#  'zhangjiakou',
#  'maarianhamina',
#  'zverinogolovskoye',
#  'ploemeur',
#  'sagua la grande',
#  'port hedland',
#  'nokaneng',
#  'wahran',
#  'palabuhanratu',
#  'palauig',
#  'sheboygan',
#  'margate',
#  'camacha',
#  'laja',
#  'alyangula',
#  'tilichiki',
#  'lasa',
#  'kathu',
#  'ostrovnoy',
#  'jubb jannin',
#  'sao joao da barra',
#  'tucuman',
#  'shumerlya',
#  'kendari',
#  'jericho',
#  'beringovskiy',
#  'mitsamiouli',
#  'jurmala',
#  'gorgan',
#  'amberley',
#  'yamada',
#  'turbat',
#  'micomeseng',
#  'tuktoyaktuk',
#  'assela',
#  'kelvington',
#  'samarai',
#  'atar',
#  'kloulklubed',
#  'murakami',
#  'sarh',
#  'ende',
#  'aasiaat',
#  'key west',
#  'tuatapere',
#  'mirabad',
#  'port lincoln',
#  'mahibadhoo',
#  'bose',
#  'kavaratti',
#  'mogadishu',
#  'ayame',
#  'roma',
#  'malakal',
#  'payakumbuh',
#  'mendahara',
#  'adana',
#  'hofn',
#  'mpika',
#  'sasovo',
#  'soissons',
#  'brainerd',
#  'kodinsk',
#  'cidreira',
#  'kariba',
#  'tsihombe',
#  'deputatskiy',
#  'pulawy',
#  'ashta',
#  'the pas',
#  'coihueco',
#  'alihe',
#  'port hardy',
#  'vryburg',
#  'cockburn town',
#  'basoko',
#  'dujuma',
#  'rawah',
#  'inhambane',
#  'umzimvubu',
#  'novoilinsk',
#  'berezanka',
#  'kruisfontein',
#  'meyungs',
#  'torbay',
#  'itarema',
#  'muroto',
#  'utiroa',
#  'mount pleasant',
#  'gari',
#  'ormara',
#  'pemangkat',
#  'siguiri',
#  'mandera',
#  'esperance',
#  'cascais',
#  'hithadhoo',
#  'mys shmidta',
#  'ayan',
#  'salta',
#  'rindal',
#  'henties bay',
#  'benguela',
#  'sakakah',
#  'norman wells',
#  'kragero',
#  'paita',
#  'san jose',
#  'port blair',
#  'petropavlovsk-kamchatskiy',
#  'pevek',
#  'talnakh',
#  'samusu',
#  'burnie',
#  'araouane',
#  'tessalit',
#  'esil',
#  'marzuq',
#  'severo-yeniseyskiy',
#  'pringsewu',
#  'sur',
#  'vaitupu',
#  'santa cruz de la palma',
#  'sola',
#  'libenge',
#  'muros',
#  'kibala',
#  'ca mau',
#  'san pedro',
#  'sistranda',
#  'port hawkesbury',
#  'huoqiu',
#  'sao filipe',
#  'grand gaube',
#  'babanusah',
#  'lagoa',
#  'rio gallegos',
#  'belaya gora',
#  'evensk',
#  'umea',
#  'inuvik',
#  'chandur',
#  'tiarei',
#  'wum',
#  'eureka',
#  'marcona',
#  'urdzhar',
#  'mantua',
#  'shahpur',
#  'mujiayingzi',
#  'lavrentiya',
#  'manokwari',
#  'grindavik',
#  'bakaly',
#  'salina',
#  'concarneau',
#  'zhangye',
#  'gizo',
#  'murgab',
#  'ino',
#  'gao',
#  'bushehr',
#  'mar del plata',
#  'louisbourg',
#  'ballina',
#  'caxito',
#  'zabid',
#  'khandyga',
#  'hasaki',
#  'shipitsyno',
#  'yanan',
#  'praya',
#  'port-gentil',
#  'anadyr',
#  'wuwei',
#  'axim',
#  'westport',
#  'epe',
#  'rudbar',
#  'zhanatas',
#  'santarem',
#  'gravelbourg',
#  'plouzane',
#  'fare',
#  'nosy varika',
#  'tacoronte',
#  'pyay',
#  'pangnirtung',
#  'thinadhoo',
#  'pacific grove',
#  'grenaa',
#  'dawson creek',
#  'gravdal',
#  'kurilsk',
#  'shakawe',
#  'buin',
#  'chapais',
#  'mehamn',
#  'honiara',
#  'bowen',
#  'ola',
#  'yelniki',
#  'bykovo',
#  'svetlogorsk',
#  'coahuayana',
#  'college',
#  'poya',
#  'blagoyevo',
#  'acapulco',
#  'tommot',
#  'kysyl-syr',
#  'vilhena',
#  'bargal',
#  'bud',
#  'naples',
#  'khani',
#  'burgeo',
#  'sakaiminato',
#  'jiddah',
#  'ugoofaaru',
#  'manggar',
#  'saint-pierre',
#  'golyshmanovo',
#  'miandrivazo',
#  'calamar',
#  'bay roberts',
#  'ixtapa',
#  'barsi',
#  'phonhong',
#  'stornoway',
#  'mango',
#  'yeletskiy',
#  'lazaro cardenas',
#  'innisfail',
#  'cap malheureux',
#  'altos',
#  'huntington',
#  'atlantic city',
#  'tazovskiy',
#  'saint anthony',
#  'alghero',
#  'kangaatsiaq',
#  'rodrigues alves',
#  'nenjiang',
#  'atyrau',
#  'vostok',
#  'harper',
#  'vytegra',
#  'constantine',
#  'izumo',
#  'inirida',
#  'bubaque',
#  'maymyo',
#  'nurmijarvi',
#  'garhshankar',
#  'takoradi',
#  'scarborough',
#  'marsabit',
#  'fort wellington',
#  'paveh',
#  'neiafu',
#  'kashan',
#  'kaka',
#  'eganville',
#  'matagami',
#  'qinzhou',
#  'keetmanshoop',
#  'guadalajara',
#  'morondava',
#  'provideniya',
#  'woodward',
#  'high level',
#  'bathurst',
#  'touros',
#  'katherine',
#  'pangkalanbuun',
#  'clyde river',
#  'altay',
#  'koutsouras',
#  'kindia',
#  'maloy',
#  'yelabuga',
#  'burica',
#  'nioki',
#  'wattegama',
#  'xiongzhou',
#  'morgan city',
#  'menongue',
#  'port shepstone',
#  'teknaf',
#  'posse',
#  'tumannyy',
#  'novikovo',
#  'itoman',
#  'prince albert',
#  'nikel',
#  'naze',
#  'pitmoaga',
#  'vavozh',
#  'ishigaki',
#  'tigil',
#  'kamenka',
#  'sao miguel do araguaia',
#  'albanel',
#  'venado tuerto',
#  'lata',
#  'luderitz',
#  'bonthe',
#  'homa bay',
#  'karpogory',
#  'pietarsaari',
#  'kinablangan',
#  'bethel',
#  'padang',
#  'alexandria',
#  'leh',
#  'finschhafen',
#  'mirnyy',
#  'jatibonico',
#  'fougamou',
#  'hirara',
#  'mangan',
#  'vagur',
#  'broken hill',
#  'kaitangata',
#  'kargil',
#  'serchhip',
#  'talaya',
#  'sechura',
#  'rajgarh',
#  'asosa',
#  'kegayli',
#  'tame',
#  'camopi',
#  'twentynine palms',
#  'aripuana',
#  'sarnia',
#  'suntar',
#  'kommunisticheskiy',
#  'caravelas',
#  'zhanakorgan',
#  'anan',
#  'chenghai',
#  'beyneu',
#  'kirillov',
#  'abha',
#  'hokitika',
#  'luau',
#  'avera',
#  'samalaeulu',
#  'doctor pedro p. pena',
#  'batangafo',
#  'peleduy',
#  'saldanha',
#  'oussouye',
#  'saint-georges',
#  'el tigre',
#  'uroteppa',
#  'maniitsoq',
#  'cuencame',
#  'dolores',
#  'labuhan',
#  'outjo',
#  'kuche',
#  'berlevag',
#  'san quintin',
#  'pilar',
#  'liberec',
#  'guarapari',
#  'fonte boa',
#  'jerico',
#  'aswan',
#  'mayo',
#  'el ocotito',
#  'machaneng',
#  'chicama']

# %%
# #beggining of te logging
import requests

from config4 import weather_api_key

# %%
url= "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=def5ed76217c4391fdd020acd61b748e

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# City not found. Skipping...
# Processing Record 2 of Set 1 | vardo
# City not found. Skipping...
# Processing Record 3 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 4 of Set 1 | thompson
# City not found. Skipping...
# Processing Record 5 of Set 1 | tasiilaq
# City not found. Skipping...
# Processing Record 6 of Set 1 | connersville
# City not found. Skipping...
# Processing Record 7 of Set 1 | chokurdakh
# City not found. Skipping...
# Processing Record 8 of Set 1 | upernavik
# City not found. Skipping...
# Processing Record 9 of Set 1 | barrow
# City not found. Skipping...
# Processing Record 10 of Set 1 | east london
# City not found. Skipping...
# Processing Record 11 of Set 1 | ushuaia
# City not found. Skipping...
# Processing Record 12 of Set 1 | richards bay
# City not found. Skipping...
# Processing Record 13 of Set 1 | kapaa
# City not found. Skipping...
# Processing Record 14 of Set 1 | castro
# City not found. Skipping...
# Processing Record 15 of Set 1 | rikitea
# City not found. Skipping...
# Processing Record 16 of Set 1 | alice springs
# City not found. Skipping...
# Processing Record 17 of Set 1 | arraial do cabo
# City not found. Skipping...
# Processing Record 18 of Set 1 | mataura
# City not found. Skipping...
# Processing Record 19 of Set 1 | cape town
# City not found. Skipping...
# Processing Record 20 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 21 of Set 1 | nohar
# City not found. Skipping...
# Processing Record 22 of Set 1 | cordoba
# City not found. Skipping...
# Processing Record 23 of Set 1 | ilulissat
# City not found. Skipping...
# Processing Record 24 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 1 | khatanga
# City not found. Skipping...
# Processing Record 26 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 27 of Set 1 | pandan
# City not found. Skipping...
# Processing Record 28 of Set 1 | havoysund
# City not found. Skipping...
# Processing Record 29 of Set 1 | ulladulla
# City not found. Skipping...
# Processing Record 30 of Set 1 | salalah
# City not found. Skipping...
# Processing Record 31 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 32 of Set 1 | zaysan
# City not found. Skipping...
# Processing Record 33 of Set 1 | codrington
# City not found. Skipping...
# Processing Record 34 of Set 1 | punta arenas
# City not found. Skipping...
# Processing Record 35 of Set 1 | severo-kurilsk
# City not found. Skipping...
# Processing Record 36 of Set 1 | dikson
# City not found. Skipping...
# Processing Record 37 of Set 1 | verkhnevilyuysk
# City not found. Skipping...
# Processing Record 38 of Set 1 | new norfolk
# City not found. Skipping...
# Processing Record 39 of Set 1 | ahipara
# City not found. Skipping...
# Processing Record 40 of Set 1 | kieta
# City not found. Skipping...
# Processing Record 41 of Set 1 | guerrero negro
# City not found. Skipping...
# Processing Record 42 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 1 | albany
# City not found. Skipping...
# Processing Record 44 of Set 1 | newport
# City not found. Skipping...
# Processing Record 45 of Set 1 | yellowknife
# City not found. Skipping...
# Processing Record 46 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 47 of Set 1 | anloga
# City not found. Skipping...
# Processing Record 48 of Set 1 | carnarvon
# City not found. Skipping...
# Processing Record 49 of Set 1 | vestmannaeyjar
# City not found. Skipping...
# Processing Record 50 of Set 1 | shimoda
# City not found. Skipping...
# Processing Record 1 of Set 2 | port alfred
# City not found. Skipping...
# Processing Record 2 of Set 2 | batagay-alyta
# City not found. Skipping...
# Processing Record 3 of Set 2 | bredasdorp
# City not found. Skipping...
# Processing Record 4 of Set 2 | lokosovo
# City not found. Skipping...
# Processing Record 5 of Set 2 | vaini
# City not found. Skipping...
# Processing Record 6 of Set 2 | aklavik
# City not found. Skipping...
# Processing Record 7 of Set 2 | russkaya polyana
# City not found. Skipping...
# Processing Record 8 of Set 2 | riyadh
# City not found. Skipping...
# Processing Record 9 of Set 2 | bathsheba
# City not found. Skipping...
# Processing Record 10 of Set 2 | vila velha
# City not found. Skipping...
# Processing Record 11 of Set 2 | souillac
# City not found. Skipping...
# Processing Record 12 of Set 2 | saint george
# City not found. Skipping...
# Processing Record 13 of Set 2 | byron bay
# City not found. Skipping...
# Processing Record 14 of Set 2 | sorland
# City not found. Skipping...
# Processing Record 15 of Set 2 | amapa
# City not found. Skipping...
# Processing Record 16 of Set 2 | half moon bay
# City not found. Skipping...
# Processing Record 17 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 2 | andenes
# City not found. Skipping...
# Processing Record 19 of Set 2 | elk city
# City not found. Skipping...
# Processing Record 20 of Set 2 | airai
# City not found. Skipping...
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | hami
# City not found. Skipping...
# Processing Record 23 of Set 2 | zhigansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | markova
# City not found. Skipping...
# Processing Record 25 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 2 | leningradskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 | fengcheng
# City not found. Skipping...
# Processing Record 28 of Set 2 | fortuna
# City not found. Skipping...
# Processing Record 29 of Set 2 | xiuyan
# City not found. Skipping...
# Processing Record 30 of Set 2 | rio grande
# City not found. Skipping...
# Processing Record 31 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 32 of Set 2 | lompoc
# City not found. Skipping...
# Processing Record 33 of Set 2 | ossora
# City not found. Skipping...
# Processing Record 34 of Set 2 | nemuro
# City not found. Skipping...
# Processing Record 35 of Set 2 | farafangana
# City not found. Skipping...
# Processing Record 36 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 37 of Set 2 | hobyo
# City not found. Skipping...
# Processing Record 38 of Set 2 | cabedelo
# City not found. Skipping...
# Processing Record 39 of Set 2 | ribeira grande
# City not found. Skipping...
# Processing Record 40 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 41 of Set 2 | plettenberg bay
# City not found. Skipping...
# Processing Record 42 of Set 2 | obidos
# City not found. Skipping...
# Processing Record 43 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 44 of Set 2 | bilibino
# City not found. Skipping...
# Processing Record 45 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 2 | bambous virieux
# City not found. Skipping...
# Processing Record 47 of Set 2 | cabo san lucas
# City not found. Skipping...
# Processing Record 48 of Set 2 | port elizabeth
# City not found. Skipping...
# Processing Record 49 of Set 2 | olafsvik
# City not found. Skipping...
# Processing Record 50 of Set 2 | alofi
# City not found. Skipping...
# Processing Record 1 of Set 3 | osinovo
# City not found. Skipping...
# Processing Record 2 of Set 3 | kjollefjord
# City not found. Skipping...
# Processing Record 3 of Set 3 | havelock
# City not found. Skipping...
# Processing Record 4 of Set 3 | kavieng
# City not found. Skipping...
# Processing Record 5 of Set 3 | katsuura
# City not found. Skipping...
# Processing Record 6 of Set 3 | ponta do sol
# City not found. Skipping...
# Processing Record 7 of Set 3 | trairi
# City not found. Skipping...
# Processing Record 8 of Set 3 | comodoro rivadavia
# City not found. Skipping...
# Processing Record 9 of Set 3 | kayerkan
# City not found. Skipping...
# Processing Record 10 of Set 3 | nikolskoye
# City not found. Skipping...
# Processing Record 11 of Set 3 | la ronge
# City not found. Skipping...
# Processing Record 12 of Set 3 | kota kinabalu
# City not found. Skipping...
# Processing Record 13 of Set 3 | avarua
# City not found. Skipping...
# Processing Record 14 of Set 3 | necochea
# City not found. Skipping...
# Processing Record 15 of Set 3 | lebu
# City not found. Skipping...
# Processing Record 16 of Set 3 | mount isa
# City not found. Skipping...
# Processing Record 17 of Set 3 | sabla
# City not found. Skipping...
# Processing Record 18 of Set 3 | victoria
# City not found. Skipping...
# Processing Record 19 of Set 3 | te anau
# City not found. Skipping...
# Processing Record 20 of Set 3 | hamilton
# City not found. Skipping...
# Processing Record 21 of Set 3 | kununurra
# City not found. Skipping...
# Processing Record 22 of Set 3 | brun
# City not found. Skipping...
# Processing Record 23 of Set 3 | inta
# City not found. Skipping...
# Processing Record 24 of Set 3 | tiksi
# City not found. Skipping...
# Processing Record 25 of Set 3 | jega
# City not found. Skipping...
# Processing Record 26 of Set 3 | bartica
# City not found. Skipping...
# Processing Record 27 of Set 3 | jalu
# City not found. Skipping...
# Processing Record 28 of Set 3 | constitucion
# City not found. Skipping...
# Processing Record 29 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 3 | hobart
# City not found. Skipping...
# Processing Record 31 of Set 3 | cherskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | qaanaaq
# City not found. Skipping...
# Processing Record 33 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 35 of Set 3 | saint-philippe
# City not found. Skipping...
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | keti bandar
# City not found. Skipping...
# Processing Record 38 of Set 3 | pisco
# City not found. Skipping...
# Processing Record 39 of Set 3 | yar-sale
# City not found. Skipping...
# Processing Record 40 of Set 3 | crotone
# City not found. Skipping...
# Processing Record 41 of Set 3 | longyearbyen
# City not found. Skipping...
# Processing Record 42 of Set 3 | launceston
# City not found. Skipping...
# Processing Record 43 of Set 3 | sabzevar
# City not found. Skipping...
# Processing Record 44 of Set 3 | nanchang
# City not found. Skipping...
# Processing Record 45 of Set 3 | nyuksenitsa
# City not found. Skipping...
# Processing Record 46 of Set 3 | ancud
# City not found. Skipping...
# Processing Record 47 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 48 of Set 3 | luchegorsk
# City not found. Skipping...
# Processing Record 49 of Set 3 | opuwo
# City not found. Skipping...
# Processing Record 50 of Set 3 | carutapera
# City not found. Skipping...
# Processing Record 1 of Set 4 | estacion coahuila
# City not found. Skipping...
# Processing Record 2 of Set 4 | seoul
# City not found. Skipping...
# Processing Record 3 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 4 of Set 4 | jinchang
# City not found. Skipping...
# Processing Record 5 of Set 4 | pineville
# City not found. Skipping...
# Processing Record 6 of Set 4 | sioux lookout
# City not found. Skipping...
# Processing Record 7 of Set 4 | raudeberg
# City not found. Skipping...
# Processing Record 8 of Set 4 | lixourion
# City not found. Skipping...
# Processing Record 9 of Set 4 | namibe
# City not found. Skipping...
# Processing Record 10 of Set 4 | iralaya
# City not found. Skipping...
# Processing Record 11 of Set 4 | toamasina
# City not found. Skipping...
# Processing Record 12 of Set 4 | mabaruma
# City not found. Skipping...
# Processing Record 13 of Set 4 | buala
# City not found. Skipping...
# Processing Record 14 of Set 4 | faya
# City not found. Skipping...
# Processing Record 15 of Set 4 | rock hill
# City not found. Skipping...
# Processing Record 16 of Set 4 | pemberton
# City not found. Skipping...
# Processing Record 17 of Set 4 | nhulunbuy
# City not found. Skipping...
# Processing Record 18 of Set 4 | kahului
# City not found. Skipping...
# Processing Record 19 of Set 4 | la palma
# City not found. Skipping...
# Processing Record 20 of Set 4 | beisfjord
# City not found. Skipping...
# Processing Record 21 of Set 4 | yinchuan
# City not found. Skipping...
# Processing Record 22 of Set 4 | independence
# City not found. Skipping...
# Processing Record 23 of Set 4 | klaksvik
# City not found. Skipping...
# Processing Record 24 of Set 4 | tromso
# City not found. Skipping...
# Processing Record 25 of Set 4 | sitka
# City not found. Skipping...
# Processing Record 26 of Set 4 | faleapuna
# City not found. Skipping...
# Processing Record 27 of Set 4 | morant bay
# City not found. Skipping...
# Processing Record 28 of Set 4 | tete
# City not found. Skipping...
# Processing Record 29 of Set 4 | sinnamary
# City not found. Skipping...
# Processing Record 30 of Set 4 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 4 | saint-francois
# City not found. Skipping...
# Processing Record 32 of Set 4 | farap
# City not found. Skipping...
# Processing Record 33 of Set 4 | gat
# City not found. Skipping...
# Processing Record 34 of Set 4 | nome
# City not found. Skipping...
# Processing Record 35 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 4 | fallon
# City not found. Skipping...
# Processing Record 37 of Set 4 | isangel
# City not found. Skipping...
# Processing Record 38 of Set 4 | faanui
# City not found. Skipping...
# Processing Record 39 of Set 4 | grande-riviere
# City not found. Skipping...
# Processing Record 40 of Set 4 | konstantinovka
# City not found. Skipping...
# Processing Record 41 of Set 4 | xichang
# City not found. Skipping...
# Processing Record 42 of Set 4 | san cristobal
# City not found. Skipping...
# Processing Record 43 of Set 4 | vanavara
# City not found. Skipping...
# Processing Record 44 of Set 4 | iqaluit
# City not found. Skipping...
# Processing Record 45 of Set 4 | the valley
# City not found. Skipping...
# Processing Record 46 of Set 4 | georgetown
# City not found. Skipping...
# Processing Record 47 of Set 4 | yeppoon
# City not found. Skipping...
# Processing Record 48 of Set 4 | mafinga
# City not found. Skipping...
# Processing Record 49 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 4 | rocha
# City not found. Skipping...
# Processing Record 1 of Set 5 | makat
# City not found. Skipping...
# Processing Record 2 of Set 5 | nishihara
# City not found. Skipping...
# Processing Record 3 of Set 5 | chuy
# City not found. Skipping...
# Processing Record 4 of Set 5 | nsanje
# City not found. Skipping...
# Processing Record 5 of Set 5 | floro
# City not found. Skipping...
# Processing Record 6 of Set 5 | lolodorf
# City not found. Skipping...
# Processing Record 7 of Set 5 | nanortalik
# City not found. Skipping...
# Processing Record 8 of Set 5 | ziro
# City not found. Skipping...
# Processing Record 9 of Set 5 | kokuy
# City not found. Skipping...
# Processing Record 10 of Set 5 | mount gambier
# City not found. Skipping...
# Processing Record 11 of Set 5 | aykhal
# City not found. Skipping...
# Processing Record 12 of Set 5 | namie
# City not found. Skipping...
# Processing Record 13 of Set 5 | sirsilla
# City not found. Skipping...
# Processing Record 14 of Set 5 | san clemente
# City not found. Skipping...
# Processing Record 15 of Set 5 | ternate
# City not found. Skipping...
# Processing Record 16 of Set 5 | geraldton
# City not found. Skipping...
# Processing Record 17 of Set 5 | bengkulu
# City not found. Skipping...
# Processing Record 18 of Set 5 | marrakesh
# City not found. Skipping...
# Processing Record 19 of Set 5 | poum
# City not found. Skipping...
# Processing Record 20 of Set 5 | bundaberg
# City not found. Skipping...
# Processing Record 21 of Set 5 | businga
# City not found. Skipping...
# Processing Record 22 of Set 5 | narsaq
# City not found. Skipping...
# Processing Record 23 of Set 5 | khorramshahr
# City not found. Skipping...
# Processing Record 24 of Set 5 | meulaboh
# City not found. Skipping...
# Processing Record 25 of Set 5 | mahebourg
# City not found. Skipping...
# Processing Record 26 of Set 5 | pauini
# City not found. Skipping...
# Processing Record 27 of Set 5 | brokopondo
# City not found. Skipping...
# Processing Record 28 of Set 5 | port macquarie
# City not found. Skipping...
# Processing Record 29 of Set 5 | butaritari
# City not found. Skipping...
# Processing Record 30 of Set 5 | praia da vitoria
# City not found. Skipping...
# Processing Record 31 of Set 5 | newburgh
# City not found. Skipping...
# Processing Record 32 of Set 5 | almaznyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | wilmington
# City not found. Skipping...
# Processing Record 34 of Set 5 | namatanai
# City not found. Skipping...
# Processing Record 35 of Set 5 | northam
# City not found. Skipping...
# Processing Record 36 of Set 5 | kodiak
# City not found. Skipping...
# Processing Record 37 of Set 5 | portland
# City not found. Skipping...
# Processing Record 38 of Set 5 | salaspils
# City not found. Skipping...
# Processing Record 39 of Set 5 | kalmunai
# City not found. Skipping...
# Processing Record 40 of Set 5 | mezen
# City not found. Skipping...
# Processing Record 41 of Set 5 | veraval
# City not found. Skipping...
# Processing Record 42 of Set 5 | hualmay
# City not found. Skipping...
# Processing Record 43 of Set 5 | san patricio
# City not found. Skipping...
# Processing Record 44 of Set 5 | bonavista
# City not found. Skipping...
# Processing Record 45 of Set 5 | okato
# City not found. Skipping...
# Processing Record 46 of Set 5 | zhangjiakou
# City not found. Skipping...
# Processing Record 47 of Set 5 | maarianhamina
# City not found. Skipping...
# Processing Record 48 of Set 5 | zverinogolovskoye
# City not found. Skipping...
# Processing Record 49 of Set 5 | ploemeur
# City not found. Skipping...
# Processing Record 50 of Set 5 | sagua la grande
# City not found. Skipping...
# Processing Record 1 of Set 6 | port hedland
# City not found. Skipping...
# Processing Record 2 of Set 6 | nokaneng
# City not found. Skipping...
# Processing Record 3 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 4 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 6 | palauig
# City not found. Skipping...
# Processing Record 6 of Set 6 | sheboygan
# City not found. Skipping...
# Processing Record 7 of Set 6 | margate
# City not found. Skipping...
# Processing Record 8 of Set 6 | camacha
# City not found. Skipping...
# Processing Record 9 of Set 6 | laja
# City not found. Skipping...
# Processing Record 10 of Set 6 | alyangula
# City not found. Skipping...
# Processing Record 11 of Set 6 | tilichiki
# City not found. Skipping...
# Processing Record 12 of Set 6 | lasa
# City not found. Skipping...
# Processing Record 13 of Set 6 | kathu
# City not found. Skipping...
# Processing Record 14 of Set 6 | ostrovnoy
# City not found. Skipping...
# Processing Record 15 of Set 6 | jubb jannin
# City not found. Skipping...
# Processing Record 16 of Set 6 | sao joao da barra
# City not found. Skipping...
# Processing Record 17 of Set 6 | tucuman
# City not found. Skipping...
# Processing Record 18 of Set 6 | shumerlya
# City not found. Skipping...
# Processing Record 19 of Set 6 | kendari
# City not found. Skipping...
# Processing Record 20 of Set 6 | jericho
# City not found. Skipping...
# Processing Record 21 of Set 6 | beringovskiy
# City not found. Skipping...
# Processing Record 22 of Set 6 | mitsamiouli
# City not found. Skipping...
# Processing Record 23 of Set 6 | jurmala
# City not found. Skipping...
# Processing Record 24 of Set 6 | gorgan
# City not found. Skipping...
# Processing Record 25 of Set 6 | amberley
# City not found. Skipping...
# Processing Record 26 of Set 6 | yamada
# City not found. Skipping...
# Processing Record 27 of Set 6 | turbat
# City not found. Skipping...
# Processing Record 28 of Set 6 | micomeseng
# City not found. Skipping...
# Processing Record 29 of Set 6 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 30 of Set 6 | assela
# City not found. Skipping...
# Processing Record 31 of Set 6 | kelvington
# City not found. Skipping...
# Processing Record 32 of Set 6 | samarai
# City not found. Skipping...
# Processing Record 33 of Set 6 | atar
# City not found. Skipping...
# Processing Record 34 of Set 6 | kloulklubed
# City not found. Skipping...
# Processing Record 35 of Set 6 | murakami
# City not found. Skipping...
# Processing Record 36 of Set 6 | sarh
# City not found. Skipping...
# Processing Record 37 of Set 6 | ende
# City not found. Skipping...
# Processing Record 38 of Set 6 | aasiaat
# City not found. Skipping...
# Processing Record 39 of Set 6 | key west
# City not found. Skipping...
# Processing Record 40 of Set 6 | tuatapere
# City not found. Skipping...
# Processing Record 41 of Set 6 | mirabad
# City not found. Skipping...
# Processing Record 42 of Set 6 | port lincoln
# City not found. Skipping...
# Processing Record 43 of Set 6 | mahibadhoo
# City not found. Skipping...
# Processing Record 44 of Set 6 | bose
# City not found. Skipping...
# Processing Record 45 of Set 6 | kavaratti
# City not found. Skipping...
# Processing Record 46 of Set 6 | mogadishu
# City not found. Skipping...
# Processing Record 47 of Set 6 | ayame
# City not found. Skipping...
# Processing Record 48 of Set 6 | roma
# City not found. Skipping...
# Processing Record 49 of Set 6 | malakal
# City not found. Skipping...
# Processing Record 50 of Set 6 | payakumbuh
# City not found. Skipping...
# Processing Record 1 of Set 7 | mendahara
# City not found. Skipping...
# Processing Record 2 of Set 7 | adana
# Processing Record 3 of Set 7 | hofn
# City not found. Skipping...
# Processing Record 4 of Set 7 | mpika
# City not found. Skipping...
# Processing Record 5 of Set 7 | sasovo
# City not found. Skipping...
# Processing Record 6 of Set 7 | soissons
# City not found. Skipping...
# Processing Record 7 of Set 7 | brainerd
# City not found. Skipping...
# Processing Record 8 of Set 7 | kodinsk
# Processing Record 9 of Set 7 | cidreira
# Processing Record 10 of Set 7 | kariba
# Processing Record 11 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 7 | deputatskiy
# Processing Record 13 of Set 7 | pulawy
# Processing Record 14 of Set 7 | ashta
# Processing Record 15 of Set 7 | the pas
# Processing Record 16 of Set 7 | coihueco
# Processing Record 17 of Set 7 | alihe
# Processing Record 18 of Set 7 | port hardy
# Processing Record 19 of Set 7 | vryburg
# Processing Record 20 of Set 7 | cockburn town
# Processing Record 21 of Set 7 | basoko
# Processing Record 22 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 23 of Set 7 | rawah
# Processing Record 24 of Set 7 | inhambane
# Processing Record 25 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 7 | novoilinsk
# Processing Record 27 of Set 7 | berezanka
# Processing Record 28 of Set 7 | kruisfontein
# Processing Record 29 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 30 of Set 7 | torbay
# Processing Record 31 of Set 7 | itarema
# Processing Record 32 of Set 7 | muroto
# Processing Record 33 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 7 | mount pleasant
# Processing Record 35 of Set 7 | gari
# Processing Record 36 of Set 7 | ormara
# Processing Record 37 of Set 7 | pemangkat
# Processing Record 38 of Set 7 | siguiri
# Processing Record 39 of Set 7 | mandera
# Processing Record 40 of Set 7 | esperance
# Processing Record 41 of Set 7 | cascais
# Processing Record 42 of Set 7 | hithadhoo
# Processing Record 43 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | salta
# Processing Record 46 of Set 7 | rindal
# Processing Record 47 of Set 7 | henties bay
# Processing Record 48 of Set 7 | benguela
# Processing Record 49 of Set 7 | sakakah
# Processing Record 50 of Set 7 | norman wells
# Processing Record 1 of Set 8 | kragero
# Processing Record 2 of Set 8 | paita
# Processing Record 3 of Set 8 | san jose
# Processing Record 4 of Set 8 | port blair
# Processing Record 5 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 8 | pevek
# Processing Record 7 of Set 8 | talnakh
# Processing Record 8 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 8 | burnie
# Processing Record 10 of Set 8 | araouane
# Processing Record 11 of Set 8 | tessalit
# Processing Record 12 of Set 8 | esil
# Processing Record 13 of Set 8 | marzuq
# Processing Record 14 of Set 8 | severo-yeniseyskiy
# Processing Record 15 of Set 8 | pringsewu
# Processing Record 16 of Set 8 | sur
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | santa cruz de la palma
# Processing Record 19 of Set 8 | sola
# Processing Record 20 of Set 8 | libenge
# Processing Record 21 of Set 8 | muros
# Processing Record 22 of Set 8 | kibala
# Processing Record 23 of Set 8 | ca mau
# Processing Record 24 of Set 8 | san pedro
# Processing Record 25 of Set 8 | sistranda
# Processing Record 26 of Set 8 | port hawkesbury
# Processing Record 27 of Set 8 | huoqiu
# Processing Record 28 of Set 8 | sao filipe
# Processing Record 29 of Set 8 | grand gaube
# Processing Record 30 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | rio gallegos
# Processing Record 33 of Set 8 | belaya gora
# Processing Record 34 of Set 8 | evensk
# Processing Record 35 of Set 8 | umea
# Processing Record 36 of Set 8 | inuvik
# Processing Record 37 of Set 8 | chandur
# Processing Record 38 of Set 8 | tiarei
# Processing Record 39 of Set 8 | wum
# Processing Record 40 of Set 8 | eureka
# Processing Record 41 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 43 of Set 8 | mantua
# Processing Record 44 of Set 8 | shahpur
# Processing Record 45 of Set 8 | mujiayingzi
# Processing Record 46 of Set 8 | lavrentiya
# Processing Record 47 of Set 8 | manokwari
# Processing Record 48 of Set 8 | grindavik
# Processing Record 49 of Set 8 | bakaly
# Processing Record 50 of Set 8 | salina
# Processing Record 1 of Set 9 | concarneau
# Processing Record 2 of Set 9 | zhangye
# Processing Record 3 of Set 9 | gizo
# Processing Record 4 of Set 9 | murgab
# Processing Record 5 of Set 9 | ino
# Processing Record 6 of Set 9 | gao
# Processing Record 7 of Set 9 | bushehr
# Processing Record 8 of Set 9 | mar del plata
# Processing Record 9 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 9 | ballina
# Processing Record 11 of Set 9 | caxito
# Processing Record 12 of Set 9 | zabid
# Processing Record 13 of Set 9 | khandyga
# Processing Record 14 of Set 9 | hasaki
# Processing Record 15 of Set 9 | shipitsyno
# Processing Record 16 of Set 9 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 9 | praya
# Processing Record 18 of Set 9 | port-gentil
# Processing Record 19 of Set 9 | anadyr
# Processing Record 20 of Set 9 | wuwei
# Processing Record 21 of Set 9 | axim
# Processing Record 22 of Set 9 | westport
# Processing Record 23 of Set 9 | epe
# Processing Record 24 of Set 9 | rudbar
# Processing Record 25 of Set 9 | zhanatas
# City not found. Skipping...
# Processing Record 26 of Set 9 | santarem
# Processing Record 27 of Set 9 | gravelbourg
# Processing Record 28 of Set 9 | plouzane
# Processing Record 29 of Set 9 | fare
# Processing Record 30 of Set 9 | nosy varika
# Processing Record 31 of Set 9 | tacoronte
# Processing Record 32 of Set 9 | pyay
# Processing Record 33 of Set 9 | pangnirtung
# Processing Record 34 of Set 9 | thinadhoo
# Processing Record 35 of Set 9 | pacific grove
# Processing Record 36 of Set 9 | grenaa
# Processing Record 37 of Set 9 | dawson creek
# Processing Record 38 of Set 9 | gravdal
# Processing Record 39 of Set 9 | kurilsk
# Processing Record 40 of Set 9 | shakawe
# Processing Record 41 of Set 9 | buin
# Processing Record 42 of Set 9 | chapais
# Processing Record 43 of Set 9 | mehamn
# Processing Record 44 of Set 9 | honiara
# Processing Record 45 of Set 9 | bowen
# Processing Record 46 of Set 9 | ola
# Processing Record 47 of Set 9 | yelniki
# Processing Record 48 of Set 9 | bykovo
# Processing Record 49 of Set 9 | svetlogorsk
# Processing Record 50 of Set 9 | coahuayana
# Processing Record 1 of Set 10 | college
# Processing Record 2 of Set 10 | poya
# Processing Record 3 of Set 10 | blagoyevo
# Processing Record 4 of Set 10 | acapulco
# Processing Record 5 of Set 10 | tommot
# Processing Record 6 of Set 10 | kysyl-syr
# Processing Record 7 of Set 10 | vilhena
# Processing Record 8 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 10 | bud
# Processing Record 10 of Set 10 | naples
# Processing Record 11 of Set 10 | khani
# Processing Record 12 of Set 10 | burgeo
# Processing Record 13 of Set 10 | sakaiminato
# Processing Record 14 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 10 | ugoofaaru
# Processing Record 16 of Set 10 | manggar
# Processing Record 17 of Set 10 | saint-pierre
# Processing Record 18 of Set 10 | golyshmanovo
# Processing Record 19 of Set 10 | miandrivazo
# Processing Record 20 of Set 10 | calamar
# Processing Record 21 of Set 10 | bay roberts
# Processing Record 22 of Set 10 | ixtapa
# Processing Record 23 of Set 10 | barsi
# Processing Record 24 of Set 10 | phonhong
# Processing Record 25 of Set 10 | stornoway
# Processing Record 26 of Set 10 | mango
# Processing Record 27 of Set 10 | yeletskiy
# City not found. Skipping...
# Processing Record 28 of Set 10 | lazaro cardenas
# Processing Record 29 of Set 10 | innisfail
# Processing Record 30 of Set 10 | cap malheureux
# Processing Record 31 of Set 10 | altos
# Processing Record 32 of Set 10 | huntington
# Processing Record 33 of Set 10 | atlantic city
# Processing Record 34 of Set 10 | tazovskiy
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | alghero
# Processing Record 37 of Set 10 | kangaatsiaq
# Processing Record 38 of Set 10 | rodrigues alves
# Processing Record 39 of Set 10 | nenjiang
# Processing Record 40 of Set 10 | atyrau
# Processing Record 41 of Set 10 | vostok
# Processing Record 42 of Set 10 | harper
# Processing Record 43 of Set 10 | vytegra
# Processing Record 44 of Set 10 | constantine
# Processing Record 45 of Set 10 | izumo
# Processing Record 46 of Set 10 | inirida
# Processing Record 47 of Set 10 | bubaque
# Processing Record 48 of Set 10 | maymyo
# Processing Record 49 of Set 10 | nurmijarvi
# Processing Record 50 of Set 10 | garhshankar
# Processing Record 1 of Set 11 | takoradi
# Processing Record 2 of Set 11 | scarborough
# Processing Record 3 of Set 11 | marsabit
# Processing Record 4 of Set 11 | fort wellington
# Processing Record 5 of Set 11 | paveh
# Processing Record 6 of Set 11 | neiafu
# Processing Record 7 of Set 11 | kashan
# Processing Record 8 of Set 11 | kaka
# Processing Record 9 of Set 11 | eganville
# Processing Record 10 of Set 11 | matagami
# Processing Record 11 of Set 11 | qinzhou
# Processing Record 12 of Set 11 | keetmanshoop
# Processing Record 13 of Set 11 | guadalajara
# Processing Record 14 of Set 11 | morondava
# Processing Record 15 of Set 11 | provideniya
# Processing Record 16 of Set 11 | woodward
# Processing Record 17 of Set 11 | high level
# Processing Record 18 of Set 11 | bathurst
# Processing Record 19 of Set 11 | touros
# Processing Record 20 of Set 11 | katherine
# Processing Record 21 of Set 11 | pangkalanbuun
# Processing Record 22 of Set 11 | clyde river
# Processing Record 23 of Set 11 | altay
# Processing Record 24 of Set 11 | koutsouras
# Processing Record 25 of Set 11 | kindia
# Processing Record 26 of Set 11 | maloy
# Processing Record 27 of Set 11 | yelabuga
# Processing Record 28 of Set 11 | burica
# City not found. Skipping...
# Processing Record 29 of Set 11 | nioki
# Processing Record 30 of Set 11 | wattegama
# Processing Record 31 of Set 11 | xiongzhou
# Processing Record 32 of Set 11 | morgan city
# Processing Record 33 of Set 11 | menongue
# Processing Record 34 of Set 11 | port shepstone
# Processing Record 35 of Set 11 | teknaf
# Processing Record 36 of Set 11 | posse
# Processing Record 37 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 11 | novikovo
# Processing Record 39 of Set 11 | itoman
# Processing Record 40 of Set 11 | prince albert
# Processing Record 41 of Set 11 | nikel
# Processing Record 42 of Set 11 | naze
# Processing Record 43 of Set 11 | pitmoaga
# Processing Record 44 of Set 11 | vavozh
# Processing Record 45 of Set 11 | ishigaki
# Processing Record 46 of Set 11 | tigil
# Processing Record 47 of Set 11 | kamenka
# Processing Record 48 of Set 11 | sao miguel do araguaia
# Processing Record 49 of Set 11 | albanel
# Processing Record 50 of Set 11 | venado tuerto
# Processing Record 1 of Set 12 | lata
# Processing Record 2 of Set 12 | luderitz
# Processing Record 3 of Set 12 | bonthe
# Processing Record 4 of Set 12 | homa bay
# Processing Record 5 of Set 12 | karpogory
# Processing Record 6 of Set 12 | pietarsaari
# Processing Record 7 of Set 12 | kinablangan
# Processing Record 8 of Set 12 | bethel
# Processing Record 9 of Set 12 | padang
# Processing Record 10 of Set 12 | alexandria
# Processing Record 11 of Set 12 | leh
# Processing Record 12 of Set 12 | finschhafen
# Processing Record 13 of Set 12 | mirnyy
# Processing Record 14 of Set 12 | jatibonico
# Processing Record 15 of Set 12 | fougamou
# Processing Record 16 of Set 12 | hirara
# Processing Record 17 of Set 12 | mangan
# Processing Record 18 of Set 12 | vagur
# Processing Record 19 of Set 12 | broken hill
# Processing Record 20 of Set 12 | kaitangata
# Processing Record 21 of Set 12 | kargil
# Processing Record 22 of Set 12 | serchhip
# Processing Record 23 of Set 12 | talaya
# Processing Record 24 of Set 12 | sechura
# Processing Record 25 of Set 12 | rajgarh
# Processing Record 26 of Set 12 | asosa
# Processing Record 27 of Set 12 | kegayli
# City not found. Skipping...
# Processing Record 28 of Set 12 | tame
# Processing Record 29 of Set 12 | camopi
# Processing Record 30 of Set 12 | twentynine palms
# Processing Record 31 of Set 12 | aripuana
# Processing Record 32 of Set 12 | sarnia
# Processing Record 33 of Set 12 | suntar
# Processing Record 34 of Set 12 | kommunisticheskiy
# Processing Record 35 of Set 12 | caravelas
# Processing Record 36 of Set 12 | zhanakorgan
# Processing Record 37 of Set 12 | anan
# Processing Record 38 of Set 12 | chenghai
# Processing Record 39 of Set 12 | beyneu
# Processing Record 40 of Set 12 | kirillov
# Processing Record 41 of Set 12 | abha
# Processing Record 42 of Set 12 | hokitika
# Processing Record 43 of Set 12 | luau
# Processing Record 44 of Set 12 | avera
# Processing Record 45 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 46 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 12 | batangafo
# Processing Record 48 of Set 12 | peleduy
# Processing Record 49 of Set 12 | saldanha
# Processing Record 50 of Set 12 | oussouye
# Processing Record 1 of Set 13 | saint-georges
# Processing Record 2 of Set 13 | el tigre
# Processing Record 3 of Set 13 | uroteppa
# City not found. Skipping...
# Processing Record 4 of Set 13 | maniitsoq
# Processing Record 5 of Set 13 | cuencame
# Processing Record 6 of Set 13 | dolores
# Processing Record 7 of Set 13 | labuhan
# Processing Record 8 of Set 13 | outjo
# Processing Record 9 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 10 of Set 13 | berlevag
# Processing Record 11 of Set 13 | san quintin
# Processing Record 12 of Set 13 | pilar
# Processing Record 13 of Set 13 | liberec
# Processing Record 14 of Set 13 | guarapari
# Processing Record 15 of Set 13 | fonte boa
# Processing Record 16 of Set 13 | jerico
# Processing Record 17 of Set 13 | aswan
# Processing Record 18 of Set 13 | mayo
# Processing Record 19 of Set 13 | el ocotito
# Processing Record 20 of Set 13 | machaneng
# Processing Record 21 of Set 13 | chicama
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Adana  36.9850   35.2881     84.72        74          40        8.05
# 1      Kodinsk  58.6881   99.1844     62.38        95           4        1.19
# 2     Cidreira -30.1811  -50.2056     68.88        71           7        7.02
# 3       Kariba -16.5167   28.8000     73.18        44          63        5.03
# 4  Deputatskiy  69.3000  139.9000     36.68        94          61        3.02
# 5       Pulawy  51.4166   21.9694     68.72        57         100        7.58
# 6        Ashta  23.0167   76.7167     75.99        87          44       13.13
# 7      The Pas  53.8251 -101.2541     75.22        64           0       10.36
# 8     Coihueco -36.6167  -71.8333     59.74        72          40        6.91
# 9        Alihe  50.5667  123.7167     65.35        96          98        2.73
#
#   Country                 Date
# 0      TR  2023-08-01 17:19:33
# 1      RU  2023-08-01 17:19:34
# 2      BR  2023-08-01 17:19:34
# 3      ZW  2023-08-01 17:19:35
# 4      RU  2023-08-01 17:19:35
# 5      PL  2023-08-01 17:19:35
# 6      IN  2023-08-01 17:19:36
# 7      CA  2023-08-01 17:19:36
# 8      CL  2023-08-01 17:19:36
# 9      CN  2023-08-01 17:19:37

# %%
new_col_order=["City","Country","Date","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed"]

# %%
city_data_df=city_data_df[new_col_order]
city_data_df

# %store city_data_df
# Out:
# Stored 'city_data_df' (DataFrame)

# %%
# Create the output file (CSV).
output_data_file = "weather_data1/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
#Get Data for Plotting

# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.strftime("%x")
today
# Out:
# '08/01/23'

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data1/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data1/Fig2.png")
# Show plot.
plt.show()

# %%
#lattude vs cloudiness
plt.scatter(lats, cloudiness, edgecolor="black",linewidths=1, marker="o", label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. cloudiness"+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data1/Fig2.png")
# Show plot.
plt.show()

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)]
# Out:
#             City Country                 Date      Lat       Lng  Max Temp  \
# 0          Adana      TR  2023-08-01 17:19:33  36.9850   35.2881     84.72
# 1        Kodinsk      RU  2023-08-01 17:19:34  58.6881   99.1844     62.38
# 4    Deputatskiy      RU  2023-08-01 17:19:35  69.3000  139.9000     36.68
# 5         Pulawy      PL  2023-08-01 17:19:35  51.4166   21.9694     68.72
# 6          Ashta      IN  2023-08-01 17:19:36  23.0167   76.7167     75.99
# ..           ...     ...                  ...      ...       ...       ...
# 282      Liberec      CZ  2023-08-01 17:26:59  50.7671   15.0562     67.59
# 285       Jerico      CO  2023-08-01 17:27:00   5.7921  -75.7860     76.78
# 286        Aswan      EG  2023-08-01 17:27:00  24.0934   32.9070    103.30
# 287         Mayo      US  2023-08-01 17:27:00  38.8876  -76.5119     81.50
# 288   El Ocotito      MX  2023-08-01 17:27:01  17.2500  -99.5667     76.05
#
#      Humidity  Cloudiness  Wind Speed
# 0          74          40        8.05
# 1          95           4        1.19
# 4          94          61        3.02
# 5          57         100        7.58
# 6          87          44       13.13
# ..        ...         ...         ...
# 282        83         100        1.99
# 285        46          43        2.24
# 286        16           0        9.22
# 287        57           0        8.05
# 288        87         100        0.67
#
# [216 rows x 9 columns]

# %%
# Perform linear regression.
(slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

# Calculate the regression line "y values" from the slope and intercept.
regress_values = x_values * slope + intercept

# Get the equation of the line.
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Create a scatter plot of the x and y values.
plt.scatter(x_values,y_values)
# Plot the regression line with the x-values and the y coordinates based on the intercept and slope.
plt.plot(x_values,regress_values,"r")
# Annotate the text for the line equation and add its coordinates.
plt.annotate(line_eq, (10,40), fontsize=15, color="red")
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Temp')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/wl/bv9m80ls7fb1_dmszjzg11hw0000gn/T/ipykernel_14529/2551385282.py in <module>
#       1 # Perform linear regression.
# ----> 2 (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
#       3
#       4 # Calculate the regression line "y values" from the slope and intercept.
#       5 regress_values = x_values * slope + intercept
#
# NameError: name 'linregress' is not defined

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Get the maximum temperature.
max_temp = city_data_df["Max Temp"]
temps = []
for temp in max_temp:
    temps.append(max(temp, 0))

# %%
series1 = pd.Series([1, 2, 3, 4])
series2 = pd.Series(['A', 'B', 'C', 'D'])

# %% [markdown]
# serie=zip(series1, series2)
# serie

# %%
ex_df=pd.DataFrame(zip(series1, series2))
ex_df
# Out:
#    0  1
# 0  1  A
# 1  2  B
# 2  3  C
# 3  4  D
